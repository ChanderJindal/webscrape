# %%
import requests 
from bs4 import BeautifulSoup

# %%
Base_Link = "https://www.readdetectiveconanarc.com/"

# %%
Status = requests.get(Base_Link)
Status
# Out:
# <Response [200]>

# %%
Page_html = Status.text
Page_html
# Out:
# '<!doctype html><html lang="en-us"><head><meta charset="utf-8"><meta name="viewport" content="width=device-width,initial-scale=1"><link rel="apple-touch-icon" sizes="57x57" href="/apple-icon-57x57.png"><link rel="apple-touch-icon" sizes="60x60" href="/apple-icon-60x60.png"><link rel="apple-touch-icon" sizes="72x72" href="/apple-icon-72x72.png"><link rel="apple-touch-icon" sizes="76x76" href="/apple-icon-76x76.png"><link rel="apple-touch-icon" sizes="114x114" href="/apple-icon-114x114.png"><link rel="apple-touch-icon" sizes="120x120" href="/apple-icon-120x120.png"><link rel="apple-touch-icon" sizes="144x144" href="/apple-icon-144x144.png"><link rel="apple-touch-icon" sizes="152x152" href="/apple-icon-152x152.png"><link rel="apple-touch-icon" sizes="180x180" href="/apple-icon-180x180.png"><link rel="icon" type="image/png" sizes="192x192" href="/android-icon-192x192.png"><link rel="icon" type="image/png" sizes="32x32" href="/favicon-32x32.png"><link rel="icon" type="image/png" sizes="96
# ...

# %%
soup = BeautifulSoup(Page_html,features="lxml")
soup
# Out:
# <!DOCTYPE html>
# ...

# %% [markdown]
# a class="column has-text-centered button-last-chapter" href="https://www.readdetectiveconanarc.com/detective-conan-chapter-1086/" title="Read Detective Conan Chapter 1086">Last Chapter ( 1086 )
#
# The TAG AT 133

# %%
Link = soup.find('a', class_ = "column has-text-centered button-last-chapter")
print(Link["href"],type(Link["href"]))
Link = str(Link["href"])
Link = Link[0:len(Link)-1]
print(Link)
# Out:
# https://www.readdetectiveconanarc.com/detective-conan-chapter-1087/ <class 'str'>
# https://www.readdetectiveconanarc.com/detective-conan-chapter-1087

# %%
MangaEdition = int(Link.split('-')[-1])
MangaEdition
# Out:
# 1087

# %% [markdown]
# Now I got the Manga Edition and Link, let's see if i can get the title

# %%
MangaStatus = requests.get(Link)
MangaStatus
# Out:
# <Response [200]>

# %%
MangaPageHTML = MangaStatus.text
print(MangaPageHTML)
# Out:
# <!doctype html><html lang="en-us"><head><meta charset="utf-8"><meta name="viewport" content="width=device-width,initial-scale=1"><link rel="apple-touch-icon" sizes="57x57" href="/apple-icon-57x57.png"><link rel="apple-touch-icon" sizes="60x60" href="/apple-icon-60x60.png"><link rel="apple-touch-icon" sizes="72x72" href="/apple-icon-72x72.png"><link rel="apple-touch-icon" sizes="76x76" href="/apple-icon-76x76.png"><link rel="apple-touch-icon" sizes="114x114" href="/apple-icon-114x114.png"><link rel="apple-touch-icon" sizes="120x120" href="/apple-icon-120x120.png"><link rel="apple-touch-icon" sizes="144x144" href="/apple-icon-144x144.png"><link rel="apple-touch-icon" sizes="152x152" href="/apple-icon-152x152.png"><link rel="apple-touch-icon" sizes="180x180" href="/apple-icon-180x180.png"><link rel="icon" type="image/png" sizes="192x192" href="/android-icon-192x192.png"><link rel="icon" type="image/png" sizes="32x32" href="/favicon-32x32.png"><link rel="icon" type="image/png" sizes="96x
# ...

# %%
soup = BeautifulSoup(MangaPageHTML,features="lxml")
soup
# Out:
# <!DOCTYPE html>
# ...

# %%
print(str(soup))
# Out:
# <!DOCTYPE html>
# ...

# %%
help(open)

# %%
f= open("MangaPageHTML.txt",encoding='utf-8', mode='w+')
#that encoding helded a ton
f.write(str(soup).replace('><','>\n<'))
# Out:
# 29817

# %%
Myalt = "Read Detective Conan Chapter " + str(MangaEdition)+" - Page 1 For Free In The Highest Quality"

# %%
pic = soup.find_all('img', alt=Myalt)

# %%
for i in pic:
    print(i,end="\n!!!!!!!!\n")
# Out:
# <img alt="Read Detective Conan Chapter 1087 - Page 1 For Free In The Highest Quality" data-lazy-src="https://cdn.readdetectiveconan.com/file/mangap/977/11087000/1.jpeg" height="1160" loading="lazy" src="data:image/svg+xml,%3Csvg xmlns=%22http://www.w3.org/2000/svg%22 viewBox=%220 0 800 1160%22/%3E" title="Read Detective Conan Chapter 1087 - Page 1 For Free In The Highest Quality" width="800"/>
# !!!!!!!!
# <img alt="Read Detective Conan Chapter 1087 - Page 1 For Free In The Highest Quality" height="1160" loading="lazy" src="https://cdn.readdetectiveconan.com/file/mangap/977/11087000/1.jpeg" title="Read Detective Conan Chapter 1087 - Page 1 For Free In The Highest Quality" width="800"/>
# !!!!!!!!

# %%
MangaEdition
# Out:
# 1087

# %%
Image = pic[0]
print(Image["data-lazy-src"])
# Out:
# https://cdn.readdetectiveconan.com/file/mangap/977/11087000/1.jpeg

# %%
soup.find('img', alt='fRead Detective Conan Chapter {MangaEdition} - Page 1 For Free In The Highest Quality')["data-lazy-src"]
